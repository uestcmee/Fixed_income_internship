# %%
raw_info="""
<ul class="matal-category-ul">
      <!-- 排除 华南 TODO -->
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/copper" class="nav-item-a
    ">
      铜
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/copper/870" class="sub-item-nav-a ">铜精矿、粗铜</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/copper/810" class="sub-item-nav-a ">电解铜</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/copper/850" class="sub-item-nav-a ">铜加工</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/copper/820" class="sub-item-nav-a ">废铜</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/copper/list/290" class="sub-item-nav-a ">其他铜产品</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/aluminum" class="nav-item-a
    ">
      铝
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/aluminum/1020" class="sub-item-nav-a ">铝土矿、氧化铝、预焙阳极、烧碱、氟化铝、阴极</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/aluminum/1010" class="sub-item-nav-a ">电解铝</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/aluminum/1030" class="sub-item-nav-a ">铝棒、铸轧卷、铝杆、铝粉</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/aluminum/1040" class="sub-item-nav-a ">铝合金、废铝</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item  active   open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/lead" class="nav-item-a
    ">
      铅
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category layout  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul">
    
      
        <li class="sub-item-nav">
            
              <a href="/lead/list/62" class="sub-item-nav-a ">铅精矿</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/lead/1220" class="sub-item-nav-a ">原生铅</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/lead/1230" class="sub-item-nav-a ">再生铅</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/lead/1240" class="sub-item-nav-a ">含铅废料</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/lead/1250" class="sub-item-nav-a ">铅蓄电池及加工产品</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/lead/list/6" class="sub-item-nav-a ">其他铅产品及废料</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/zinc" class="nav-item-a
    ">
      锌
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/zinc/list/116" class="sub-item-nav-a ">锌精矿</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/zinc/1420" class="sub-item-nav-a ">精炼锌</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/zinc/1460" class="sub-item-nav-a ">镀锌、氧化锌、压铸锌合金</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/tin" class="nav-item-a
    ">
      锡
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/tin/1610" class="sub-item-nav-a ">锡精矿</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/tin/1620" class="sub-item-nav-a ">精炼锡</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/tin/1630" class="sub-item-nav-a ">焊锡、锡粉、锡化合物、锡基轴承合金</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/tin/list/11398" class="sub-item-nav-a ">广东废锡</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/nickel" class="nav-item-a
    ">
      镍
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/nickel/1820" class="sub-item-nav-a ">镍矿</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/nickel/1810" class="sub-item-nav-a ">一级镍</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/nickel/1830" class="sub-item-nav-a ">镍铁</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/nickel/1840" class="sub-item-nav-a ">镍盐</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/stainless-steel" class="nav-item-a
    ">
      不锈钢
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/stainless-steel/list/11418" class="sub-item-nav-a ">不锈钢</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/stainless-steel/list/11444" class="sub-item-nav-a ">废不锈钢</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/chromium" class="nav-item-a
    ">
      铬
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/chromium/list/11548" class="sub-item-nav-a ">铬矿</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/chromium/list/11538" class="sub-item-nav-a ">铬铁</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/precious-metals" class="nav-item-a
    ">
      贵金属
  </a>

  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/steel" class="nav-item-a
    ">
      钢铁
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/steel/2810" class="sub-item-nav-a ">螺纹钢</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/steel/2820" class="sub-item-nav-a ">热轧板卷</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/steel/list/12128" class="sub-item-nav-a ">其他钢材品种</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/steel/2840" class="sub-item-nav-a ">铁矿</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/manganese" class="nav-item-a
    ">
      锰
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-left">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/manganese/2010" class="sub-item-nav-a ">电解锰</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/manganese/2020" class="sub-item-nav-a ">进口锰矿</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/manganese/2030" class="sub-item-nav-a ">硅锰合金</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/manganese/list/11526" class="sub-item-nav-a ">锰化合物</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/silicon" class="nav-item-a
    ">
      硅
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-right">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/silicon/list/11162" class="sub-item-nav-a ">硅石、石油焦、精煤、木片、木炭、电极</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/silicon/2420" class="sub-item-nav-a ">金属硅</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/silicon/2430" class="sub-item-nav-a ">铝合金、有机硅、多晶硅、硅粉、三氯氢硅</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/new-energy" class="nav-item-a
    guli-item">
      钴锂
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-right">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/new-energy/2610" class="sub-item-nav-a ">钴</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/new-energy/2620" class="sub-item-nav-a ">锂</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/new-energy/2630" class="sub-item-nav-a ">前驱体及正极材料</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/new-energy/2640" class="sub-item-nav-a ">锂电新能源</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/new-energy/2650" class="sub-item-nav-a ">负极材料、隔膜、电解液</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/antimony" class="nav-item-a
    ">
      锑
  </a>

  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/tungsten" class="nav-item-a
    ">
      钨
  </a>

  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/in-ge-ga" class="nav-item-a
    ">
      铟镓锗
  </a>

  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/bi-se-te" class="nav-item-a
    ">
      铋硒碲
  </a>

  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/magnesium" class="nav-item-a
    ">
      镁
  </a>

  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/minor-metals" class="nav-item-a
    ">
      小金属
  </a>

  
    
        

<div class="metal_sub_category    metal-sub-category-list  metal-sub-category-list-right">
  <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
    
      
        <li class="sub-item-nav">
            
              <a href="/minor-metals/410" class="sub-item-nav-a ">锑</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/minor-metals/420" class="sub-item-nav-a ">铟镓锗</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/minor-metals/430" class="sub-item-nav-a ">铋硒碲</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/minor-metals/list/11798" class="sub-item-nav-a ">钨钼铬铌</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/minor-metals/list/11812" class="sub-item-nav-a ">镁钛锆钒</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/minor-metals/list/11830" class="sub-item-nav-a ">镉砷铍铼</a>
            
        </li>
      
    
      
        <li class="sub-item-nav">
            
              <a href="/minor-metals/list/11824" class="sub-item-nav-a ">钾钠钙</a>
            
        </li>
      
    
  </ul>
</div>   

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/rare-earth" class="nav-item-a
    ">
      稀土
  </a>

  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item     open-nav-item open_nav_item  new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
  <a href="/metal-scraps" class="nav-item-a
    ">
      废金属
  </a>

  
    
        

            
    
  

</li>

            
        
      
          
      
      
        
            
              


<li class="nav_item       nav_item_hover" style="width: 54px;">
  <a href="/cj" class="nav-item-a
    ">
      长江
  </a>

  

</li>

            
        
      
          
      
      
        
      
          
      
      
        
      
          
      
      
          
      
      
        
      
          
      
      
        
      
          
      
      
        
      
          
      
      
        
            
              
            
        
      
          
      
      
        
            
              
            
        
      
          
      
      
        
            
              
            
        
      
      
      </ul>
"""

# %%
product_list=[]
for one in soup.find_all('li',class_='open-nav-item'):
    need=one.find_all('a',class_='nav-item-a')[0]
    product=(need.attrs['href'][1:])
    product_list.append(product)
product_list
# Out:
# ['copper',
#  'aluminum',
#  'lead',
#  'zinc',
#  'tin',
#  'nickel',
#  'stainless-steel',
#  'chromium',
#  'precious-metals',
#  'steel',
#  'manganese',
#  'silicon',
#  'new-energy',
#  'antimony',
#  'tungsten',
#  'in-ge-ga',
#  'bi-se-te',
#  'magnesium',
#  'minor-metals',
#  'rare-earth',
#  'metal-scraps']

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(raw_info,'lxml')
soup
# Out:
# <html><body><ul class="matal-category-ul">
# <!-- 排除 华南 TODO -->
# <li class="nav_item open-nav-item open_nav_item new-nav-item new_nav_item nav_item_hover" style="width: 54px;">
# <a class="nav-item-a" href="/copper">
#       铜
#   </a>
# <div class="metal_sub_category metal-sub-category-list metal-sub-category-list-left">
# <ul class="metal-sub-category-list-ul metal_sub_category_list_ul" style="max-height: 0px; visibility: hidden;">
# <li class="sub-item-nav">
# <a class="sub-item-nav-a" href="/copper/870">铜精矿、粗铜</a>
# </li>
# <li class="sub-item-nav">
# <a class="sub-item-nav-a" href="/copper/810">电解铜</a>
# </li>
# <li class="sub-item-nav">
# <a class="sub-item-nav-a" href="/copper/850">铜加工</a>
# </li>
# <li class="sub-item-nav">
# <a class="sub-item-nav-a" href="/copper/820">废铜</a>
# </li>
# <li class="sub-item-nav">
# <a class="sub-item-nav-a" href="/copper/list/290">其他铜产品</a>
# </li>
# </ul>
# </div>
# </li>
# ...
