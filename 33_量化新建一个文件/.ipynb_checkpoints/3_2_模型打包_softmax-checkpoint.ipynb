# %%
# 设置绘图
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
#设置字体为SimHei显示中文
plt.rcParams['font.sans-serif'] = 'SimHei'
#设置正常显示字符
plt.rcParams['axes.unicode_minus'] = False

import pandas as pd
import numpy as np
import xgboost
import math

# %%
from keras.models import Sequential  # 采用贯序模型
from keras.layers import Input, Dense, Dropout, Activation,LSTM
from keras.models import Model
from keras.optimizers import SGD
import numpy as np

seed = 7
np.random.seed(seed)

# %%
df=pd.read_csv('T_30min with indicators.csv',index_col=0)
df.dropna(inplace=True)
df

df.insert(0,'rr',df['close_30min']/df['open_30min']-1)
df
# Out:
#                         rr  open_30min  high_30min  low_30min  close_30min  \
# 2018/12/5 10:15  -0.000051      97.330      97.355     97.270       97.325
# 2018/12/5 10:45  -0.000051      97.325      97.345     97.295       97.320
# 2018/12/5 11:15   0.000000      97.320      97.355     97.295       97.320
# 2018/12/5 13:15  -0.000103      97.320      97.330     97.280       97.310
# 2018/12/5 13:45  -0.000308      97.310      97.310     97.230       97.280
# ...                    ...         ...         ...        ...          ...
# 2020/12/17 13:30  0.000206      97.245      97.280     97.220       97.265
# 2020/12/17 14:00  0.000000      97.260      97.290     97.255       97.260
# 2020/12/17 14:30 -0.000360      97.260      97.280     97.215       97.225
# 2020/12/17 15:00 -0.000154      97.225      97.250     97.210       97.210
# 2020/12/17 15:15  0.000103      97.210      97.225     97.185       97.220
#
#                   volume_30min  MACD_12_26_30min  MACD_24_52_30min  \
# 2018/12/5 10:15           6163          0.095268          0.086420
# 2018/12/5 10:45           2858          0.105405          0.095897
# 2018/12/5 11:15           2179          0.114574          0.105283
# 2018/12/5 13:15           2418          0.122234          0.114218
# 2018/12/5 13:45           4172          0.127790          0.122286
# ...                        ...               ...               ...
# 2020/12/17 13:30          4083         -0.009183         -0.016558
# 2020/12/17 14:00          3955         -0.012000         -0.018119
# 2020/12/17 14:30          4976         -0.015243         -0.020067
# 2020/12/17 15:00          3783         -0.018786         -0.022355
# 2020/12/17 15:15          3898         -0.022131         -0.024727
#
#                   RSI_14_30min  RSI_28_30min  ...  CCI_28_5min  MFI_14_5min  \
# 2018/12/5 10:15      76.154149     66.967819  ...    66.519337    42.975289
# 2018/12/5 10:45      75.643044     66.740675  ...    44.962498    32.421742
# 2018/12/5 11:15      75.643044     66.740675  ...    34.367080    66.403160
# 2018/12/5 13:15      74.483530     66.257296  ...   -60.527454    53.042032
# 2018/12/5 13:45      70.968888     64.797242  ...  -122.022621    30.130904
# ...                        ...           ...  ...          ...          ...
# 2020/12/17 13:30     42.354323     45.410411  ...   -43.927568    42.711543
# 2020/12/17 14:00     41.918905     45.190073  ...   -33.205985    36.489343
# 2020/12/17 14:30     38.903922     43.652499  ...  -189.247312    28.732549
# 2020/12/17 15:00     37.653970     43.002217  ...  -148.346128    26.445989
# 2020/12/17 15:15     39.059688     43.583254  ...  -107.477258    33.198392
#
#                   MFI_20_5min  MFI_28_5min  AR_10_5min  BR_10_5min  \
# 2018/12/5 10:15     47.466434    39.133915   73.913043   70.212766
# 2018/12/5 10:45     45.310396    44.576565   84.375000   90.322581
# 2018/12/5 11:15     36.336553    45.447290  117.391304  121.739130
# 2018/12/5 13:15     56.076101    33.969069  136.363636  136.363636
# 2018/12/5 13:45     40.149974    42.214855   65.625000   65.625000
# ...                       ...          ...         ...         ...
# 2020/12/17 13:30    30.602935    39.539902  123.809524  123.809524
# 2020/12/17 14:00    37.241049    27.206273  192.857143  173.333333
# 2020/12/17 14:30    34.617901    29.758558   78.571429   75.862069
# 2020/12/17 15:00    29.630146    36.590212  100.000000   82.142857
# 2020/12/17 15:15    32.193037    32.459139  135.000000  113.636364
#
#                   AR_20_5min  BR_20_5min  AR_26_5min  BR_26_5min
# 2018/12/5 10:15   110.389610  194.202899   90.909091  151.000000
# 2018/12/5 10:45   102.597403  181.428571  108.791209  185.185185
# 2018/12/5 11:15   111.111111  116.981132  108.988764  178.048780
# 2018/12/5 13:15   118.181818  130.952381  113.636364  111.940299
# 2018/12/5 13:45    82.456140   81.034483   84.507042   91.304348
# ...                      ...         ...         ...         ...
# 2020/12/17 13:30   61.428571   56.944444   79.761905   78.823529
# 2020/12/17 14:00  104.255319  104.255319   72.500000   68.292683
# 2020/12/17 14:30  108.510638  102.040816   96.923077   92.537313
# 2020/12/17 15:00  113.953488  102.173913  117.241379  108.196721
# 2020/12/17 15:15  120.454546  108.510638  136.000000  116.363636
#
# [4453 rows x 85 columns]

# %%
from sklearn.decomposition import PCA

pca = PCA()   #保留所有成分
pca.fit(df)
pca.components_ #返回模型的各个特征向量
pca.explained_variance_ratio_ #返回各个成分各自的方差百分比(也称贡献率）

# 通过上面的结果选择几个贡献率
pca = PCA(3)  #选取累计贡献率大于80%的主成分（3个主成分）
pca.fit(df)
df_dim = pca.transform(df)   #降低维度

df_dim=pd.DataFrame(df_dim)
df_dim;

# %%
sns.heatmap(df.corr())
plt.savefig('corr.svg')
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
                if colname in dataset.columns:
                    del dataset[colname] # deleting the column from the dataset
    return dataset
df=correlation(df,0.8)
df
# Out:
#                         rr  open_30min  volume_30min  MACD_12_26_30min  \
# 2018/12/5 10:15  -0.000051      97.330          6163          0.095268
# 2018/12/5 10:45  -0.000051      97.325          2858          0.105405
# 2018/12/5 11:15   0.000000      97.320          2179          0.114574
# 2018/12/5 13:15  -0.000103      97.320          2418          0.122234
# 2018/12/5 13:45  -0.000308      97.310          4172          0.127790
# ...                    ...         ...           ...               ...
# 2020/12/17 13:30  0.000206      97.245          4083         -0.009183
# 2020/12/17 14:00  0.000000      97.260          3955         -0.012000
# 2020/12/17 14:30 -0.000360      97.260          4976         -0.015243
# 2020/12/17 15:00 -0.000154      97.225          3783         -0.018786
# 2020/12/17 15:15  0.000103      97.210          3898         -0.022131
#
#                   RSI_14_30min  ADX_14_30min  ADX_28_30min  K_9_3_30min  \
# 2018/12/5 10:15      76.154149     34.582740     17.412006    78.371526
# 2018/12/5 10:45      75.643044     36.335907     18.241438    79.655091
# 2018/12/5 11:15      75.643044     38.003958     19.056562    79.852365
# 2018/12/5 13:15      74.483530     39.305217     19.786591    78.568244
# 2018/12/5 13:45      70.968888     39.706727     20.306258    75.045496
# ...                        ...           ...           ...          ...
# 2020/12/17 13:30     42.354323     14.599749      9.135214    27.022200
# 2020/12/17 14:00     41.918905     14.452013      8.970579    24.518865
# 2020/12/17 14:30     38.903922     14.848171      8.951933    17.933212
# 2020/12/17 15:00     37.653970     15.280952      8.951276    11.955475
# 2020/12/17 15:15     39.059688     16.008500      9.037605    12.831427
#
#                   TRIX_30_9_30min  TRIX_60_15_30min  ...  BR_20_30min  \
# 2018/12/5 10:15          0.003048          0.003868  ...   196.178344
# 2018/12/5 10:45          0.003401          0.003860  ...   271.304348
# 2018/12/5 11:15          0.003791          0.003861  ...   252.500000
# 2018/12/5 13:15          0.004213          0.003871  ...   231.250000
# 2018/12/5 13:45          0.004658          0.003890  ...   212.500000
# ...                           ...               ...  ...          ...
# 2020/12/17 13:30        -0.001338         -0.000331  ...    71.794872
# 2020/12/17 14:00        -0.001344         -0.000342  ...    72.549020
# 2020/12/17 14:30        -0.001358         -0.000354  ...    67.295597
# 2020/12/17 15:00        -0.001382         -0.000367  ...    69.281046
# 2020/12/17 15:15        -0.001417         -0.000382  ...    73.972603
#
#                   volume_5min  MACD_12_26_5min  WillR_14_5min  TRIX_30_9_5min  \
# 2018/12/5 10:15         458.0         0.063166     -20.895522        1.465998
# 2018/12/5 10:45         373.0         0.053877     -52.380952        1.041360
# 2018/12/5 11:15         317.0         0.039195     -53.846154        0.744857
# 2018/12/5 13:15         323.0         0.022795     -60.000000        0.505980
# 2018/12/5 13:45         321.0         0.008951     -56.521739        0.363591
# ...                       ...              ...            ...             ...
# 2020/12/17 13:30        416.0        -0.021691     -35.714286       -0.001175
# 2020/12/17 14:00        838.0        -0.015611     -42.857143       -0.001507
# 2020/12/17 14:30        970.0        -0.012716     -86.666667       -0.001645
# 2020/12/17 15:00        910.0        -0.014616    -100.000000       -0.001730
# 2020/12/17 15:15       1141.0        -0.016387     -61.111111       -0.001790
#
#                   MFI_14_5min  MFI_28_5min  AR_10_5min  AR_20_5min  BR_26_5min
# 2018/12/5 10:15     42.975289    39.133915   73.913043  110.389610  151.000000
# 2018/12/5 10:45     32.421742    44.576565   84.375000  102.597403  185.185185
# 2018/12/5 11:15     66.403160    45.447290  117.391304  111.111111  178.048780
# 2018/12/5 13:15     53.042032    33.969069  136.363636  118.181818  111.940299
# 2018/12/5 13:45     30.130904    42.214855   65.625000   82.456140   91.304348
# ...                       ...          ...         ...         ...         ...
# 2020/12/17 13:30    42.711543    39.539902  123.809524   61.428571   78.823529
# 2020/12/17 14:00    36.489343    27.206273  192.857143  104.255319   68.292683
# 2020/12/17 14:30    28.732549    29.758558   78.571429  108.510638   92.537313
# 2020/12/17 15:00    26.445989    36.590212  100.000000  113.953488  108.196721
# 2020/12/17 15:15    33.198392    32.459139  135.000000  120.454546  116.363636
#
# [4453 rows x 24 columns]

# %%
dataset=df

def create_dataset_softmax(dataset:np.ndarray, look_back:int):  # 后一个数据和前look_back个数据有关系
    assert not (isinstance(dataset,np.ndarray) and isinstance(dataset,pd.core.frame.DataFrame)) ,'输入数据格式不符合要求，使用pandas或numpy'
    dataset=np.array(dataset)

    dataX, dataY = [],[]
    rr=[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back)]
        dataX.append(a)  # .apeend方法追加元素
        rr.append(dataset[:,0][i + look_back])
        if dataset[:,0][i + look_back]>0:
            dataY.append([1,0]) #【1,0】表示涨了
        else:
            dataY.append([0,1])
        
    rr=np.array(rr)   
    rr=np.reshape(rr,(rr.shape[0],-1))
    # dataY.append(dataset[:,0][i + look_back]) #此处Y要第一列（收益率） 
        
    dataX,dataY=np.array(dataX),np.array(dataY)
    dataX,dataY=np.reshape(dataX,(dataX.shape[0],-1)),np.reshape(dataY,(dataY.shape[0],-1))# 转变为二维数据
    
    # 进行归一化
    from sklearn.preprocessing import MinMaxScaler
    scalerX = MinMaxScaler(feature_range=(0, 1))  # 归一化0-1
    scalerX.fit(dataX)
    dataX=scalerX.transform(dataX)

    scalerY = MinMaxScaler(feature_range=(0, 1))  # 归一化0-1
    scalerY.fit(dataY)
    dataY=scalerY.transform(dataY)
    return np.array(dataX), np.array(dataY),scalerX,scalerY ,rr # 生成输入数据和输出数据

totX, totY, scalerX, scalerY,rr = create_dataset_softmax(np.array(dataset), look_back=20)  # 训练输入输出

# %%
def split_dataset(dataset):
    dataset=np.array(dataset)
    train_size = int(len(dataset) * 0.67)  # %67的训练集，剩下测试集
    test_size = len(dataset) - train_size
    train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]  # 训练集和测试集    
    return train,test

trainX,testX=split_dataset(totX)
trainY,testY=split_dataset(totY)
trainR,testR=split_dataset(rr)
print(trainX.shape)
# Out:
# (2969, 480)

# %%
tBatchSize = 128
'''第一步：选择模型'''
model = Sequential()  # 采用贯序模型

'''第二步：构建网络层'''
'''构建网络只是构建了一个网络结构，并定义网络的参数，此时还没有输入的数据集'''
# 构建的第一个层作为输入层
# Dense 这是第一个隐藏层，并附带定义了输入层，该隐含层有500个神经元。输入则是 784个节点
model.add(Dense(50, input_shape=(trainX.shape[1],)))  # 输入层，28*28=784 输入层将二维矩阵换成了一维向量输入
model.add(Activation('relu'))  # 激活函数是relu
model.add(Dropout(0.5))  # 采用50%的dropout  随机取一半进行训练

# 构建的第2个层作为隐藏层2， （如果加上输入层，实际上是第三层）
model.add(Dense(50))  # 隐藏层节点50个
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(50))  # 隐藏层3，节点50个
model.add(Activation('relu'))
# model.add(Dropout(0.5))

# 构建的第3个层作为输出层
model.add(Dense(2))  # 
model.add(Activation('softmax'))  # 最后一层用softmax作为激活函数
'''第三步：网络优化和编译'''
#   lr：大于0的浮点数，学习率
#   momentum：大于0的浮点数，动量参数
#   decay：大于0的浮点数，每次更新后的学习率衰减值
#   nesterov：布尔值，确定是否使用Nesterov动量
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)  # 优化函数，设定学习率（lr）等参数


model.compile(loss='categorical_crossentropy', optimizer=sgd)  #均方误差作为损失函数，优化器为Adam

# %%
model.fit(trainX, trainY, batch_size=tBatchSize, epochs=50, shuffle=True, verbose=1, validation_split=0.3)
print('模型训练完成')
# model.evaluate(testX, testY, batch_size=200, verbose=0)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7049 - val_loss: 0.6941
# Epoch 2/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6966 - val_loss: 0.6947
# Epoch 3/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6972 - val_loss: 0.6935
# Epoch 4/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6974 - val_loss: 0.6941
# Epoch 5/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6955 - val_loss: 0.6935
# Epoch 6/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6923 - val_loss: 0.6935
# Epoch 7/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6931 - val_loss: 0.6936
# Epoch 8/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6917 - val_loss: 0.6937
# Epoch 9/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6938 - val_loss: 0.6931
# Epoch 10/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6940 - val_loss: 0.6932
# Epoch 11/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6929 - val_loss: 0.6936
# Epoch 12/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6943 - val_loss: 0.6930
# Epoch 13/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6935 - val_loss: 0.6931
# Epoch 14/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6926 - val_loss: 0.6934
# Epoch 15/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6926 - val_loss: 0.6931
# Epoch 16/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6932 - val_loss: 0.6928
# Epoch 17/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6934 - val_loss: 0.6930
# Epoch 18/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6925 - val_loss: 0.6934
# Epoch 19/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6927 - val_loss: 0.6936
# Epoch 20/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6931 - val_loss: 0.6935
# Epoch 21/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6938 - val_loss: 0.6936
# Epoch 22/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6926 - val_loss: 0.6931
# Epoch 23/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6930 - val_loss: 0.6933
# Epoch 24/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6930 - val_loss: 0.6939
# Epoch 25/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6919 - val_loss: 0.6933
# Epoch 26/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6939 - val_loss: 0.6943
# Epoch 27/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6925 - val_loss: 0.6937
# Epoch 28/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6934 - val_loss: 0.6935
# Epoch 29/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6925 - val_loss: 0.6934
# Epoch 30/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6924 - val_loss: 0.6931
# Epoch 31/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6919 - val_loss: 0.6935
# Epoch 32/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6914 - val_loss: 0.6937
# Epoch 33/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6928 - val_loss: 0.6934
# Epoch 34/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6913 - val_loss: 0.6935
# Epoch 35/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6914 - val_loss: 0.6938
# Epoch 36/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6916 - val_loss: 0.6936
# Epoch 37/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6917 - val_loss: 0.6940
# Epoch 38/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6929 - val_loss: 0.6934
# Epoch 39/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6920 - val_loss: 0.6934
# Epoch 40/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6917 - val_loss: 0.6935
# Epoch 41/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6917 - val_loss: 0.6934
# Epoch 42/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6910 - val_loss: 0.6935
# Epoch 43/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6919 - val_loss: 0.6935
# Epoch 44/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6911 - val_loss: 0.6936
# Epoch 45/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6912 - val_loss: 0.6937
# Epoch 46/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6896 - val_loss: 0.6931
# Epoch 47/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6930 - val_loss: 0.6937
# Epoch 48/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6913 - val_loss: 0.6929
# Epoch 49/50
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6876 - val_loss: 0.6936
# Epoch 50/50
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6901 - val_loss: 0.6936
# 模型训练完成

# %%
def result_plot_softmax(result,test=True):
    result_raw=scalerY.inverse_transform(result)
    testY_raw=scalerY.inverse_transform(testY)
    

    result_df=pd.DataFrame({'pred':result_raw[:,0]>result_raw[:,1]}) 
    if test:
        result_df['real']=testR[:,0]
    else:
        result_df['real']=trainR[:,0]

    result_df['buy']=(result_df['pred']==True) #只做多
    result_df['buy_and_sell']=result_df['pred'].apply(lambda x:1 if x>0 else -1 ) # 加做空

    result_df['real_return']=(1+result_df['real']).cumprod()
    result_df['stg_buy']=((result_df['real']*result_df['buy'])+1).cumprod()
    result_df['stg_buy_and_sell']=((result_df['real']*result_df['buy_and_sell'])+1).cumprod()
    return result_df


result= model.predict(testX, batch_size=tBatchSize, verbose=0)
result_df=result_plot_softmax(result)
result_df
# Out:
#        pred      real    buy  buy_and_sell  real_return   stg_buy  \
# 0     False -0.000587  False            -1     0.999413  1.000000
# 1     False -0.000147  False            -1     0.999267  1.000000
# 2     False -0.000391  False            -1     0.998875  1.000000
# 3     False -0.000979  False            -1     0.997898  1.000000
# 4     False  0.000490  False            -1     0.998387  1.000000
# ...     ...       ...    ...           ...          ...       ...
# 1458  False -0.000257  False            -1     0.990146  1.006598
# 1459  False  0.000206  False            -1     0.990349  1.006598
# 1460   True  0.000000   True             1     0.990349  1.006598
# 1461   True -0.000360   True             1     0.989993  1.006236
# 1462   True -0.000154   True             1     0.989840  1.006081
#
#       stg_buy_and_sell
# 0             1.000587
# 1             1.000734
# 2             1.001125
# 3             1.002105
# 4             1.001614
# ...                ...
# 1458          1.023032
# 1459          1.022822
# 1460          1.022822
# 1461          1.022454
# 1462          1.022296
#
# [1463 rows x 7 columns]

# %%
result_df[['real_return','stg_buy','stg_buy_and_sell']].plot()

from source.Ratio import ratio
result_df['buy_rr']=result_df['real']*result_df['buy']
result_df['buy_sell_rr']=result_df['real']*result_df['buy_and_sell']
ratio().cal_ratio(pd.DataFrame(result_df[['real','buy_rr','buy_sell_rr']]),day=False)
plt.legend(['期货','策略（多仓）','策略（多空仓）'])
plt.show()

from source.Ratio import ratio

result_df['buy_rr']=result_df['real']*result_df['buy']
result_df['buy_sell_rr']=result_df['real']*result_df['buy_and_sell']
ratio().cal_ratio(pd.DataFrame(result_df[['real','buy_rr','buy_sell_rr']]),day=False)
# Out:
#                   real      buy_rr  buy_sell_rr
# 信息比率         -0.147278    0.119172     0.336234
# 累计收益率         0.989840    1.006081     1.022296
# 每日收益率        -0.000007    0.000004     0.000015
# 最大每日收益        0.003900    0.003900     0.003900
# 最大每日损失       -0.003362   -0.002556    -0.002599
# 上涨天数        688.000000  455.000000   707.000000
# 下跌天数        724.000000  472.000000   705.000000
# 不变天数         51.000000  536.000000    51.000000
# 胜率            0.487252    0.490831     0.500708
# 上涨时平均每日收益率    0.000567    0.000566     0.000575
# 下跌时平均每日收益率   -0.000553   -0.000532    -0.000545
# 盈亏比           1.026472    1.063379     1.055442
# 最大回撤          0.036885    0.014309     0.016604

# %% [markdown]
# ## LSTM

# %%
# 调整数据的输入格式，24维*10天
trainX_LSTM=np.reshape(trainX,(trainX.shape[0],24,-1)) 
testX_LSTM=np.reshape(testX,(testX.shape[0],24,-1))

trainX_LSTM.shape
# Out:
# (2969, 24, 20)

# %%
model = Sequential()

model.add(LSTM(11, input_shape=(24,20)))  # 隐层11个神经元 ,输入数据格式为24维*10天
model.add(Dense(2))
model.add(Activation('softmax'))  # 最后一层用softmax作为激活函数

model.compile(loss='mse', optimizer='adam')  # 评价函数mse，优化器adam
model.fit(trainX_LSTM, trainY, epochs=50, batch_size=100, verbose=1)  # 100次迭代
# Out:
# Epoch 1/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2501
# Epoch 2/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2499
# Epoch 3/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2497
# Epoch 4/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2494
# Epoch 5/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2497
# Epoch 6/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2493
# Epoch 7/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2493
# Epoch 8/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2494
# Epoch 9/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2495
# Epoch 10/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2494
# Epoch 11/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2493
# Epoch 12/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2489
# Epoch 13/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2492
# Epoch 14/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2491
# Epoch 15/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2491
# Epoch 16/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2490
# Epoch 17/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2490
# Epoch 18/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2496
# Epoch 19/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2492
# Epoch 20/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2489
# Epoch 21/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2490
# Epoch 22/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2493
# Epoch 23/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2493
# Epoch 24/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2490
# Epoch 25/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2486
# Epoch 26/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2488
# Epoch 27/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2487
# Epoch 28/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2486
# Epoch 29/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2488
# Epoch 30/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2485
# Epoch 31/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2491
# Epoch 32/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2486
# Epoch 33/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2485
# Epoch 34/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2489
# Epoch 35/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2487
# Epoch 36/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2485
# Epoch 37/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2486
# Epoch 38/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2487
# Epoch 39/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2483
# Epoch 40/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2485
# Epoch 41/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2485
# Epoch 42/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2483
# Epoch 43/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2483
# Epoch 44/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2481
# Epoch 45/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2484
# Epoch 46/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2481
# Epoch 47/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2481
# Epoch 48/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2486
# Epoch 49/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2483
# Epoch 50/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2482

# %% [markdown]
# ### 训练集

# %%
# 根据模型获取预测结果  为了节约计算内存，也是分组（batch）load到内存中的，
result= model.predict(trainX_LSTM, batch_size=tBatchSize, verbose=0)

result_df=result_plot_softmax(result,test=False)
result_df[['real_return','stg_buy','stg_buy_and_sell']].plot(title='LSTM')
plt.legend(['期货','策略（多仓）','策略（多空仓）'])
plt.show()

# %% [markdown]
# ### 测试集

# %%
# 根据模型获取预测结果  为了节约计算内存，也是分组（batch）load到内存中的，
result= model.predict(testX_LSTM, batch_size=tBatchSize, verbose=0)

result_df=result_plot_softmax(result)
plt.show()
result_df[['real_return','stg_buy','stg_buy_and_sell']].plot(title='LSTM')
plt.legend(['期货','策略（多仓）','策略（多空仓）'])
plt.show()

# %%
from source.Ratio import ratio

result_df['buy_rr']=result_df['real']*result_df['buy']
result_df['buy_sell_rr']=result_df['real']*result_df['buy_and_sell']
ratio().cal_ratio(pd.DataFrame(result_df[['real','buy_rr','buy_sell_rr']]),day=False)
# Out:
#                   real       buy_rr  buy_sell_rr
# 信息比率         -0.147278     0.594707     0.706444
# 累计收益率         0.989840     1.018724     1.047824
# 每日收益率        -0.000007     0.000013     0.000032
# 最大每日收益        0.003900     0.002371     0.003362
# 最大每日损失       -0.003362    -0.002153    -0.003900
# 上涨天数        688.000000   212.000000   733.000000
# 下跌天数        724.000000   203.000000   679.000000
# 不变天数         51.000000  1048.000000    51.000000
# 胜率            0.487252     0.510843     0.519122
# 上涨时平均每日收益率    0.000567     0.000526     0.000571
# 下跌时平均每日收益率   -0.000553    -0.000457    -0.000547
# 盈亏比           1.026472     1.149797     1.043746
# 最大回撤          0.036885     0.008131     0.011983
